# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# Load Apple Stock data directly
df = yf.download('AAPL', 
                  start='2020-01-01', 
                  end='2024-01-01')

print(df.shape)
df.head()
